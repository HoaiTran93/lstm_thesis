# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, RegressorMixin, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
import math
import time
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %%
sns.set_style("whitegrid")

# %% [markdown]
# ### Part 1: Data Pre-processing

# %%
df = pd.read_csv("../resources/data/discords/nyc_taxi/nyc_taxi.csv",header=None, usecols = [1], names=['Passengers'])
dates = pd.date_range('7/1/2014', periods=17520, freq='30Min')
df = df.set_index(dates)
df
# Out:
#                      Passengers
# 2014-07-01 00:00:00       10844
# 2014-07-01 00:30:00        8127
# 2014-07-01 01:00:00        6210
# 2014-07-01 01:30:00        4656
# 2014-07-01 02:00:00        3820
# ...                         ...
# 2015-06-30 21:30:00       20223
# 2015-06-30 22:00:00       19967
# 2015-06-30 22:30:00       18865
# 2015-06-30 23:00:00       16893
# 2015-06-30 23:30:00       14242
#
# [17520 rows x 1 columns]

# %%
df.plot(figsize=(30,10))
plt.show()
